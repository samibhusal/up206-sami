# %% [markdown]
# # **Examining childcare data**

# %% [markdown]
# I start by importing a new module called geopandas to my notebook.

# %%
import geopandas as gpd

# %% [markdown]
# Next, I need to import data. Here, I have downloaded data on childcare and familychild care from Department of Social Services."https://www.ccld.dss.ca.gov/carefacilitysearch/DownloadData
# The data is in csv format.

# %% [markdown]
# But, I first want to know where my file is located.

# %%
pwd
# Out:
# '/home/jovyan/up206a/Weeks/Week02/Childcare data'

# %% [markdown]
# Now I use relative path to point to where data for childcare is located using :/

# %%
childcare = gpd.read_file('../Childcare data/childcarecenters.csv')

# %% [markdown]
# Next, I want to know data type for childcare data.

# %%
type(childcare)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %% [markdown]
# But, what does my data actually even look like?

# %%
childcare.head()
# Out:
#      Facility Type Facility Number  \
# 0  DAY CARE CENTER       197416900
# 1  DAY CARE CENTER       191607790
# 2  DAY CARE CENTER       197416698
# 3  DAY CARE CENTER       197493820
# 4  DAY CARE CENTER       384001195
#
#                                      Facility Name  \
# 0  107TH. STREET ELEMENTARY SCHOOL CSPP/HEAD START
# 1                            10TH STREET PRESCHOOL
# 2              186TH STREET ELEMENTARY SCHOOL CSPP
# 3                  1ST CLASS PREPARATORY PRESCHOOL
# 4                                1ST PLACE 2 START
#
#                           Licensee Facility Administrator  \
# 0   LAUSD EARLY CHILDHOOD EDUCATON        RIOS, REUBEN M.
# 1                WASSON, CINDY LEE          WASSON, CINDY
# 2  LAUSD/EARLY CHILDHOOD EDUCATION        REED, MARCIA S.
# 3            1ST CLASS PREPARATORY       MARRISCHIA DAVIS
# 4                1ST PLACE 2 START           SANDRA DAVIS
#
#   Facility Telephone Number                Facility Address  Facility City  \
# 0            (323) 756-8137  146 EAST 107TH. STREET ROOM K4    LOS ANGELES
# 1            (310) 458-4088                1444 10TH STREET   SANTA MONICA
# 2            (310) 324-1153   1581 WEST 186TH STREET ROOM 9        GARDENA
# 3            (310) 925-6394                   3459 MC MANUS    CULVER CITY
# 4            (415) 333-2659              1252 SUNNYDALE AVE  SAN FRANCISCO
#
#   Facility State Facility Zip  ...               POC Dates  \
# 0             CA        90003  ...
# 1             CA        90401  ...              08/29/2019
# 2             CA        90248  ...
# 3             CA        90232  ...
# 4             CA        94134  ...  08/17/2016, 08/17/2016
#
#                                   All Visit Dates  \
# 0              03/26/2019, 03/26/2019, 05/06/2016
# 1  07/29/2019, 01/25/2018, 03/11/2016, 03/11/2016
# 2                                      12/13/2016
# 3                                      10/11/2018
# 4  09/12/2019, 10/24/2017, 08/24/2016, 08/03/2016
#
#                Inspection Visit Dates Inspect TypeA Inspect TypeB  \
# 0              03/26/2019, 05/06/2016             0             0
# 1              07/29/2019, 01/25/2018             0             1
# 2                          12/13/2016             0             0
# 3                                                 0             0
# 4  09/12/2019, 10/24/2017, 08/03/2016             0             2
#
#   Other Visit Dates Other TypeA Other TypeB  \
# 0        03/26/2019           0           0
# 1                             0           0
# 2                             0           0
# 3        10/11/2018           0           0
# 4        08/24/2016           0           0
#
#   Complaint Info- Date, #Sub Aleg, # Inc Aleg, # Uns Aleg, # TypeA, # TypeB ...  \
# 0                                      No Complaints
# 1                                         03/14/2016
# 2                                      No Complaints
# 3                                      No Complaints
# 4                                      No Complaints
#
#   geometry
# 0     None
# 1     None
# 2     None
# 3     None
# 4     None
#
# [5 rows x 32 columns]

# %% [markdown]
# Next, I see what a sample of the childcare dataset looks like.

# %%
childcare.sample()
# Out:
#         Facility Type Facility Number                  Facility Name  \
# 9739  DAY CARE CENTER       197412046  RAINBOW EARLY LEARNING CENTER
#
#                         Licensee Facility Administrator  \
# 9739  SMITH, BRYAN & SMITH, TOKE             TOKE SMITH
#
#      Facility Telephone Number        Facility Address Facility City  \
# 9739            (818) 993-0424  20819 PARTHENIA STREET      WINNETKA
#
#      Facility State Facility Zip  ... POC Dates  \
# 9739             CA        91306  ...
#
#                                         All Visit Dates  \
# 9739  02/12/2019, 11/28/2018, 05/10/2017, 03/28/2016...
#
#                   Inspection Visit Dates Inspect TypeA Inspect TypeB  \
# 9739  11/28/2018, 05/10/2017, 03/22/2016             0             0
#
#      Other Visit Dates Other TypeA Other TypeB  \
# 9739        03/28/2016           0           0
#
#      Complaint Info- Date, #Sub Aleg, # Inc Aleg, # Uns Aleg, # TypeA, # TypeB ...  \
# 9739                                         02/14/2019
#
#      geometry
# 9739     None
#
# [1 rows x 32 columns]

# %% [markdown]
# Now that I know what variables are in this dataset, let's see what data types I have.

# %%
childcare.dtypes
# Out:
# Facility Type                                                                      object
# Facility Number                                                                    object
# Facility Name                                                                      object
# Licensee                                                                           object
# Facility Administrator                                                             object
# Facility Telephone Number                                                          object
# Facility Address                                                                   object
# Facility City                                                                      object
# Facility State                                                                     object
# Facility Zip                                                                       object
# County Name                                                                        object
# Regional Office                                                                    object
# Facility Capacity                                                                  object
# Facility Status                                                                    object
# License First Date                                                                 object
# Closed Date                                                                        object
# Last Visit Date                                                                    object
# Inspection Visits                                                                  object
# Complaint Visits                                                                   object
# Other Visits                                                                       object
# Total Visits                                                                       object
# Citation Numbers                                                                   object
# POC Dates                                                                          object
# All Visit Dates                                                                    object
# Inspection Visit Dates                                                             object
# Inspect TypeA                                                                      object
# Inspect TypeB                                                                      object
# Other Visit Dates                                                                  object
# Other TypeA                                                                        object
# Other TypeB                                                                        object
# Complaint Info- Date, #Sub Aleg, # Inc Aleg, # Uns Aleg, # TypeA, # TypeB ...      object
# geometry                                                                         geometry
# dtype: object

# %% [markdown]
# There definitely was another command to get this info. It is the info command

# %%
childcare.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 19005 entries, 0 to 19004
# Data columns (total 32 columns):
#  #   Column                                                                         Non-Null Count  Dtype
# ---  ------                                                                         --------------  -----
#  0   Facility Type                                                                  19005 non-null  object
#  1   Facility Number                                                                19005 non-null  object
#  2   Facility Name                                                                  19005 non-null  object
#  3   Licensee                                                                       19005 non-null  object
#  4   Facility Administrator                                                         19005 non-null  object
#  5   Facility Telephone Number                                                      19005 non-null  object
#  6   Facility Address                                                               19005 non-null  object
#  7   Facility City                                                                  19005 non-null  object
#  8   Facility State                                                                 19005 non-null  object
#  9   Facility Zip                                                                   19005 non-null  object
#  10  County Name                                                                    19005 non-null  object
#  11  Regional Office                                                                19005 non-null  object
#  12  Facility Capacity                                                              19005 non-null  object
#  13  Facility Status                                                                19005 non-null  object
#  14  License First Date                                                             19005 non-null  object
#  15  Closed Date                                                                    19005 non-null  object
#  16  Last Visit Date                                                                19005 non-null  object
#  17  Inspection Visits                                                              19005 non-null  object
#  18  Complaint Visits                                                               19005 non-null  object
#  19  Other Visits                                                                   19005 non-null  object
#  20  Total Visits                                                                   19005 non-null  object
#  21  Citation Numbers                                                               19005 non-null  object
#  22  POC Dates                                                                      19005 non-null  object
#  23  All Visit Dates                                                                19005 non-null  object
#  24  Inspection Visit Dates                                                         19005 non-null  object
#  25  Inspect TypeA                                                                  19005 non-null  object
#  26  Inspect TypeB                                                                  19005 non-null  object
#  27  Other Visit Dates                                                              19005 non-null  object
#  28  Other TypeA                                                                    19005 non-null  object
#  29  Other TypeB                                                                    19005 non-null  object
#  30  Complaint Info- Date, #Sub Aleg, # Inc Aleg, # Uns Aleg, # TypeA, # TypeB ...  19005 non-null  object
#  31  geometry                                                                       0 non-null      geometry
# dtypes: geometry(1), object(31)
# memory usage: 4.6+ MB

# %% [markdown]
# So, most of our data type is object, aka string. That's a pretty big dataset. But, how big. How many rows and columns are there?

# %%
childcare.shape
# Out:
# (19005, 32)

# %% [markdown]
# We know that this dataset contrains 32 columns and 19,005 rows. But, that's too many columns. I definitely do not need information on inspection visits, complaint visits, and all of that. Let's trim our data.

# %%
# list of desired column names
desired_columns = ['Facility Type','Facility Number','Facility Name','Licensee', 'Facility City','Facility Address', 'Facility City', 'Facility State', 'Facility Zip', 'County Name']

# subset based on desired columns
childcare[desired_columns]
# Out:
#                     Facility Type Facility Number  \
# 0                 DAY CARE CENTER       197416900
# 1                 DAY CARE CENTER       191607790
# 2                 DAY CARE CENTER       197416698
# 3                 DAY CARE CENTER       197493820
# 4                 DAY CARE CENTER       384001195
# ...                           ...             ...
# 19000  SCHOOL AGE DAY CARE CENTER       070211880
# 19001  SCHOOL AGE DAY CARE CENTER       198003136
# 19002  SCHOOL AGE DAY CARE CENTER       376700498
# 19003  SCHOOL AGE DAY CARE CENTER       304370618
# 19004  SCHOOL AGE DAY CARE CENTER       376300205
#
#                                          Facility Name  \
# 0      107TH. STREET ELEMENTARY SCHOOL CSPP/HEAD START
# 1                                10TH STREET PRESCHOOL
# 2                  186TH STREET ELEMENTARY SCHOOL CSPP
# 3                      1ST CLASS PREPARATORY PRESCHOOL
# 4                                    1ST PLACE 2 START
# ...                                                ...
# 19000             YWCA OF CONTRA COSTA - HIDDEN VALLEY
# 19001                            Y.M.C.A GLB LOS ALTOS
# 19002                            ZAMORANO KLASSIC KIDS
# 19003                ZIGGURAT CHILD DEVELOPMENT CENTER
# 19004                   ZION CHRISTIAN LEARNING CENTER
#
#                                        Licensee  Facility City  \
# 0                LAUSD EARLY CHILDHOOD EDUCATON    LOS ANGELES
# 1                             WASSON, CINDY LEE   SANTA MONICA
# 2               LAUSD/EARLY CHILDHOOD EDUCATION        GARDENA
# 3                         1ST CLASS PREPARATORY    CULVER CITY
# 4                             1ST PLACE 2 START  SAN FRANCISCO
# ...                                         ...            ...
# 19000               YWCA OF CONTRA COSTA COUNTY       MARTINEZ
# 19001                    Y.M.C.A. GLB LOS ALTOS     LONG BEACH
# 19002                            HARMONIUM INC.      SAN DIEGO
# 19003  CHILDREN'S CREATIVE LEARNING CENTERS LLC  LAGUNA NIGUEL
# 19004                               PINGEL,KARA      FALLBROOK
#
#                      Facility Address  Facility City Facility State  \
# 0      146 EAST 107TH. STREET ROOM K4    LOS ANGELES             CA
# 1                    1444 10TH STREET   SANTA MONICA             CA
# 2       1581 WEST 186TH STREET ROOM 9        GARDENA             CA
# 3                       3459 MC MANUS    CULVER CITY             CA
# 4                  1252 SUNNYDALE AVE  SAN FRANCISCO             CA
# ...                               ...            ...            ...
# 19000                     510 GLACIER       MARTINEZ             CA
# 19001                 1720 BELLFLOWER     LONG BEACH             CA
# 19002               2655 CASEY STREET      SAN DIEGO             CA
# 19003                24000 AVILA ROAD  LAGUNA NIGUEL             CA
# 19004             1405 E FALLBROOK ST      FALLBROOK             CA
#
#       Facility Zip    County Name
# 0            90003    LOS ANGELES
# 1            90401    LOS ANGELES
# 2            90248    LOS ANGELES
# 3            90232    LOS ANGELES
# 4            94134  SAN FRANCISCO
# ...            ...            ...
# 19000        94553   CONTRA COSTA
# 19001        90815    LOS ANGELES
# 19002        92139      SAN DIEGO
# 19003        92677         ORANGE
# 19004        92028      SAN DIEGO
#
# [19005 rows x 10 columns]

# %% [markdown]
# These outputs are temporary. So, we need to save my trimmed content. Let's create a new variable for the trimmed data.

# %%
childcaretrim=childcare[desired_columns]
childcaretrim
# Out:
#                     Facility Type Facility Number  \
# 0                 DAY CARE CENTER       197416900
# 1                 DAY CARE CENTER       191607790
# 2                 DAY CARE CENTER       197416698
# 3                 DAY CARE CENTER       197493820
# 4                 DAY CARE CENTER       384001195
# ...                           ...             ...
# 19000  SCHOOL AGE DAY CARE CENTER       070211880
# 19001  SCHOOL AGE DAY CARE CENTER       198003136
# 19002  SCHOOL AGE DAY CARE CENTER       376700498
# 19003  SCHOOL AGE DAY CARE CENTER       304370618
# 19004  SCHOOL AGE DAY CARE CENTER       376300205
#
#                                          Facility Name  \
# 0      107TH. STREET ELEMENTARY SCHOOL CSPP/HEAD START
# 1                                10TH STREET PRESCHOOL
# 2                  186TH STREET ELEMENTARY SCHOOL CSPP
# 3                      1ST CLASS PREPARATORY PRESCHOOL
# 4                                    1ST PLACE 2 START
# ...                                                ...
# 19000             YWCA OF CONTRA COSTA - HIDDEN VALLEY
# 19001                            Y.M.C.A GLB LOS ALTOS
# 19002                            ZAMORANO KLASSIC KIDS
# 19003                ZIGGURAT CHILD DEVELOPMENT CENTER
# 19004                   ZION CHRISTIAN LEARNING CENTER
#
#                                        Licensee  Facility City  \
# 0                LAUSD EARLY CHILDHOOD EDUCATON    LOS ANGELES
# 1                             WASSON, CINDY LEE   SANTA MONICA
# 2               LAUSD/EARLY CHILDHOOD EDUCATION        GARDENA
# 3                         1ST CLASS PREPARATORY    CULVER CITY
# 4                             1ST PLACE 2 START  SAN FRANCISCO
# ...                                         ...            ...
# 19000               YWCA OF CONTRA COSTA COUNTY       MARTINEZ
# 19001                    Y.M.C.A. GLB LOS ALTOS     LONG BEACH
# 19002                            HARMONIUM INC.      SAN DIEGO
# 19003  CHILDREN'S CREATIVE LEARNING CENTERS LLC  LAGUNA NIGUEL
# 19004                               PINGEL,KARA      FALLBROOK
#
#                      Facility Address  Facility City Facility State  \
# 0      146 EAST 107TH. STREET ROOM K4    LOS ANGELES             CA
# 1                    1444 10TH STREET   SANTA MONICA             CA
# 2       1581 WEST 186TH STREET ROOM 9        GARDENA             CA
# 3                       3459 MC MANUS    CULVER CITY             CA
# 4                  1252 SUNNYDALE AVE  SAN FRANCISCO             CA
# ...                               ...            ...            ...
# 19000                     510 GLACIER       MARTINEZ             CA
# 19001                 1720 BELLFLOWER     LONG BEACH             CA
# 19002               2655 CASEY STREET      SAN DIEGO             CA
# 19003                24000 AVILA ROAD  LAGUNA NIGUEL             CA
# 19004             1405 E FALLBROOK ST      FALLBROOK             CA
#
#       Facility Zip    County Name
# 0            90003    LOS ANGELES
# 1            90401    LOS ANGELES
# 2            90248    LOS ANGELES
# 3            90232    LOS ANGELES
# 4            94134  SAN FRANCISCO
# ...            ...            ...
# 19000        94553   CONTRA COSTA
# 19001        90815    LOS ANGELES
# 19002        92139      SAN DIEGO
# 19003        92677         ORANGE
# 19004        92028      SAN DIEGO
#
# [19005 rows x 10 columns]

# %% [markdown]
# Now that my data is clean. Let's do some queries!!Let's start with facility city.

# %%
childcaretrim.loc[childcare['Facility City']=='Los Angeles']
# Out:
# Empty DataFrame
# Columns: [Facility Type, Facility Number, Facility Name, Licensee, Facility City, Facility Address, Facility City, Facility State, Facility Zip, County Name]
# Index: []

# %% [markdown]
# Not sure why this code did not give us an actual subset of facilities in Los Angeles, maybe because the dataset is huge? Let's try another way to query data.

# %%
childcaretrim[childcare.County Name == 'Los Angeles']
# Out:
#   File "<ipython-input-29-4e0f1e39908d>", line 1
#     childcaretrim[childcare.County Name == 'Los Angeles']
#                                    ^
# SyntaxError: invalid syntax

# %% [markdown]
# Maybe let's try quering zip code to see if that works.

# %%
childcaretrim.query("Facility Zip == '94134'")
# Out:
# Traceback (most recent call last):
#
#   File "/opt/conda/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3343, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   File "<ipython-input-21-cde0ceb7bab7>", line 1, in <module>
#     childcaretrim.query("Facility Zip == '94134'")
#
#   File "/opt/conda/lib/python3.8/site-packages/pandas/core/frame.py", line 3231, in query
#     res = self.eval(expr, **kwargs)
#
#   File "/opt/conda/lib/python3.8/site-packages/pandas/core/frame.py", line 3346, in eval
#     return _eval(expr, inplace=inplace, **kwargs)
#
#   File "/opt/conda/lib/python3.8/site-packages/pandas/core/computation/eval.py", line 332, in eval
#     parsed_expr = Expr(expr, engine=engine, parser=parser, env=env)
#
#   File "/opt/conda/lib/python3.8/site-packages/pandas/core/computation/expr.py", line 764, in __init__
#     self.terms = self.parse()
#
#   File "/opt/conda/lib/python3.8/site-packages/pandas/core/computation/expr.py", line 781, in parse
#     return self._visitor.visit(self.expr)
#
#   File "/opt/conda/lib/python3.8/site-packages/pandas/core/computation/expr.py", line 371, in visit
#     raise e
#
#   File "/opt/conda/lib/python3.8/site-packages/pandas/core/computation/expr.py", line 367, in visit
#     node = ast.fix_missing_locations(ast.parse(clean))
#
#   File "/opt/conda/lib/python3.8/ast.py", line 47, in parse
#     return compile(source, filename, mode, flags,
#
#   File "<unknown>", line 1
#     Facility Zip =='94134'
#              ^
# SyntaxError: invalid syntax

# %% [markdown]
# That query also did not work. Let's try something different in the meantime. Let's describe our trimmed data.

# %%
childcaretrim.describe()
# Out:
#           Facility Type Facility Number               Facility Name  \
# count             19005           19005                       19005
# unique                4           19005                       14977
# top     DAY CARE CENTER       197418903  KINDERCARE LEARNING CENTER
# freq              13105               1                         272
#
#                     Licensee Facility City        Facility Address  \
# count                  19005         19005                   19005
# unique                  9776           989                   14695
# top     CATALYST FAMILY INC.   LOS ANGELES  1740 PRAIRIE CITY ROAD
# freq                     233          1030                      12
#
#        Facility City Facility State Facility Zip  County Name
# count          19005          19005        19005        19005
# unique           989              1         1420           58
# top      LOS ANGELES             CA        95630  LOS ANGELES
# freq            1030          19005           69         4481

# %% [markdown]
# Looks like we have 4 types of facility types and 19,005 facilities in this dataset, of which 9776 are unique licensees. We have data from 58 unique counties and 989 unique cities, which basically here are counties iwthin California. Our dataset includes 1420 zip code data.

# %% [markdown]
# Moving forward, suppose I want to only look at childcare facilities in Los Angeles County and examine that selected dataset. How can I select that subset? Let's try

# %%
childcaretrim.query("County Name=='LOS ANGELES'")
# Out:
# Traceback (most recent call last):
#
#   File "/opt/conda/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3343, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   File "<ipython-input-26-283d9b43ba9c>", line 1, in <module>
#     childcaretrim.query("County Name=='LOS ANGELES'")
#
#   File "/opt/conda/lib/python3.8/site-packages/pandas/core/frame.py", line 3231, in query
#     res = self.eval(expr, **kwargs)
#
#   File "/opt/conda/lib/python3.8/site-packages/pandas/core/frame.py", line 3346, in eval
#     return _eval(expr, inplace=inplace, **kwargs)
#
#   File "/opt/conda/lib/python3.8/site-packages/pandas/core/computation/eval.py", line 332, in eval
#     parsed_expr = Expr(expr, engine=engine, parser=parser, env=env)
#
#   File "/opt/conda/lib/python3.8/site-packages/pandas/core/computation/expr.py", line 764, in __init__
#     self.terms = self.parse()
#
#   File "/opt/conda/lib/python3.8/site-packages/pandas/core/computation/expr.py", line 781, in parse
#     return self._visitor.visit(self.expr)
#
#   File "/opt/conda/lib/python3.8/site-packages/pandas/core/computation/expr.py", line 371, in visit
#     raise e
#
#   File "/opt/conda/lib/python3.8/site-packages/pandas/core/computation/expr.py", line 367, in visit
#     node = ast.fix_missing_locations(ast.parse(clean))
#
#   File "/opt/conda/lib/python3.8/ast.py", line 47, in parse
#     return compile(source, filename, mode, flags,
#
#   File "<unknown>", line 1
#     County Name =='LOS ANGELES'
#            ^
# SyntaxError: invalid syntax

# %% [markdown]
# That's an invalid syntax error once again. Ask how to do data query in class or office hour next week.
